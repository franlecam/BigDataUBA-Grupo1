# %%
import pandas as pd
import unicodedata
from pandas.api.types import is_categorical_dtype

# --- utilidades ---
def quitar_acentos(s):
    if pd.isna(s): 
        return s
    return ''.join(c for c in unicodedata.normalize('NFKD', str(s)) if not unicodedata.combining(c))

def to_Int64(series):
    s = pd.to_numeric(series, errors="coerce")
    return s.round().astype("Int64")

def to_float64(series):
    return pd.to_numeric(series, errors="coerce").astype("float64")

# =========================
# CARGA
# =========================
# r"C:\Users\Usuario\Desktop\Maestria\Programacion\BigDataUBA-Grupo1\TP1\Bases de datos\usu_individual_T125.xlsx"
# r"C:\Users\Usuario\Desktop\Maestria\Programacion\BigDataUBA-Grupo1\TP1\Bases de datos\Individual_t105.dta"

ruta_dta  = r"C:\Users\AGUSTIN\Desktop\Individual_t105.dta"      # 2005
ruta_xlsx = r"C:\Users\AGUSTIN\Desktop\usu_individual_T125.xlsx" # 2025

base_2005 = pd.read_stata(ruta_dta)
base_2025 = pd.read_excel(ruta_xlsx)

# =========================
# FILTRO POR REGIÓN
# =========================
# 2005: región textual -> quedarnos solo "Patagonica/Patagónica"
if "region" in base_2005.columns:
    reg_txt = base_2005["region"].astype("string").map(quitar_acentos).str.lower()
    base_2005 = base_2005[reg_txt == "patagonica"]

# 2025: región numérica == 44
if "REGION" in base_2025.columns:
    base_2025 = base_2025[base_2025["REGION"] == 44]

# =========================
# VARIABLES A CONSERVAR
# =========================
vars_identif = ["CODUSU","NRO_HOGAR","COMPONENTE","H15","ANO4","TRIMESTRE","REGION","PONDERA"]
vars_analit  = ["CH04","CH06","CH07","CH08","NIVEL_ED","ESTADO","CAT_INAC","IPCF",
                "CH15","PP02H","PP02I","PP10A","T_VI","ITF","PP02E"]
vars_keep    = vars_identif + vars_analit

# Normalizar nombres a MAYÚSCULAS
base_2005.columns = [c.upper() for c in base_2005.columns]
base_2025.columns = [c.upper() for c in base_2025.columns]

# Filtrar solo columnas disponibles
base_2005 = base_2005[[c for c in vars_keep if c in base_2005.columns]]
base_2025 = base_2025[[c for c in vars_keep if c in base_2025.columns]]

# =========================
# VISTA RÁPIDA
# =========================
print("=== Base 2005 (filtrada y con columnas seleccionadas) ===")
print("Shape:", base_2005.shape)
print(base_2005.head())

print("\n=== Base 2025 (filtrada y con columnas seleccionadas) ===")
print("Shape:", base_2025.shape)
print(base_2025.head())

# =========================
# ESTADÍSTICAS
# =========================

print("\n==============================")
print("ESTADÍSTICAS — BASE 2005")
print("==============================")
for col in base_2005.columns:
    s = base_2005[col]
    print(f"\n--- {col} ({s.dtype}) ---")
    if str(s.dtype) in ["int64", "float64", "Int64"]:
        if s.nunique(dropna=True) <= 50:
            vc = s.value_counts(dropna=False)
            pct = (vc / len(s) * 100).round(2)
            print(pd.DataFrame({"n": vc, "%": pct}))
        else:
            print(s.describe())
    else:
        vc = s.astype("string").value_counts(dropna=False)
        pct = (vc / len(s) * 100).round(2)
        print(pd.DataFrame({"n": vc, "%": pct}))

print("\n==============================")
print("ESTADÍSTICAS — BASE 2025")
print("==============================")
for col in base_2025.columns:
    s = base_2025[col]
    print(f"\n--- {col} ({s.dtype}) ---")
    if str(s.dtype) in ["int64", "float64", "Int64"]:
        if s.nunique(dropna=True) <= 50:
            vc = s.value_counts(dropna=False)
            pct = (vc / len(s) * 100).round(2)
            print(pd.DataFrame({"n": vc, "%": pct}))
        else:
            print(s.describe())
    else:
        vc = s.astype("string").value_counts(dropna=False)
        pct = (vc / len(s) * 100).round(2)
        print(pd.DataFrame({"n": vc, "%": pct}))
# Out:
# === Base 2005 (filtrada y con columnas seleccionadas) ===
# Shape: (3229, 23)
#          CODUSU  NRO_HOGAR COMPONENTE  H15    ANO4       TRIMESTRE  \
# 43801  125814          1.0        1.0   Sí  2005.0  1er. Trimestre
# 43802  125814          1.0        2.0   Sí  2005.0  1er. Trimestre
# 43803  125814          1.0        3.0   Sí  2005.0  1er. Trimestre
# 43804  125814          1.0        4.0  0.0  2005.0  1er. Trimestre
# 43805  125814          1.0        5.0  0.0  2005.0  1er. Trimestre
#
#            REGION  PONDERA   CH04  CH06  ...            ESTADO  \
# 43801  Patagónica    249.0  Varón  46.0  ...           Ocupado
# 43802  Patagónica    249.0  Mujer  32.0  ...          Inactivo
# 43803  Patagónica    249.0  Varón  14.0  ...          Inactivo
# 43804  Patagónica    249.0  Varón   9.0  ...  Menor de 10 años
# 43805  Patagónica    249.0  Mujer   3.0  ...  Menor de 10 años
#
#               CAT_INAC   IPCF                             CH15 PP02H  PP02I  \
# ...

# %%
# =========================
# Chequeo de tipos
# =========================
vars_keep = [
    "CODUSU","NRO_HOGAR","COMPONENTE","H15","ANO4","TRIMESTRE","REGION","PONDERA",
    "CH04","CH06","CH07","CH08","NIVEL_ED","ESTADO","CAT_INAC","IPCF",
    "CH15","PP02H","PP02I","PP10A","T_VI","ITF","PP02E"
]

# Trabajamos sobre copias y normalizamos nombres a MAYÚSCULAS
b2005_chk = base_2005.copy()
b2025_chk = base_2025.copy()
b2005_chk.columns = [c.upper() for c in b2005_chk.columns]
b2025_chk.columns = [c.upper() for c in b2025_chk.columns]

# Subconjuntos solo con las columnas presentes en cada base
b2005_chk = b2005_chk[[c for c in vars_keep if c in b2005_chk.columns]]
b2025_chk = b2025_chk[[c for c in vars_keep if c in b2025_chk.columns]]

# Tipos por base
print("📊 DTA 2005 dtypes (sin conversiones):\n", b2005_chk.dtypes)
print("\n📊 XLSX 2025 dtypes (sin conversiones):\n", b2025_chk.dtypes)

# Comparación lado a lado
comparacion = []
for col in sorted(set(b2005_chk.columns).union(set(b2025_chk.columns))):
    comparacion.append({
        "Variable": col,
        "En_2005": col in b2005_chk.columns,
        "Dtype_2005": str(b2005_chk[col].dtype) if col in b2005_chk.columns else None,
        "En_2025": col in b2025_chk.columns,
        "Dtype_2025": str(b2025_chk[col].dtype) if col in b2025_chk.columns else None,
        "Coincide": (str(b2005_chk[col].dtype) == str(b2025_chk[col].dtype))
                    if (col in b2005_chk.columns and col in b2025_chk.columns) else None
    })

comp_df = pd.DataFrame(comparacion)
print("\n🔎 Comparación de dtypes (2005 vs 2025) — sin conversiones:")
print(comp_df)
# Out:
# 📊 DTA 2005 dtypes (sin conversiones):
#  CODUSU          object
# NRO_HOGAR      float64
# COMPONENTE    category
# H15           category
# ANO4           float64
# TRIMESTRE     category
# REGION        category
# PONDERA        float64
# CH04          category
# CH06          category
# CH07          category
# CH08          category
# NIVEL_ED      category
# ESTADO        category
# CAT_INAC      category
# IPCF           float64
# CH15          category
# PP02H         category
# PP02I         category
# PP10A         category
# T_VI           float64
# ITF            float64
# PP02E         category
# dtype: object
#
# 📊 XLSX 2025 dtypes (sin conversiones):
#  CODUSU         object
# NRO_HOGAR       int64
# COMPONENTE      int64
# H15             int64
# ANO4            int64
# TRIMESTRE       int64
# REGION          int64
# PONDERA         int64
# CH04            int64
# CH06            int64
# CH07            int64
# CH08          float64
# NIVEL_ED        int64
# ...

# %%
# =========================
# Chequeo de tipos
# =========================
vars_keep = [
    "CODUSU","NRO_HOGAR","COMPONENTE","H15","ANO4","TRIMESTRE","REGION","PONDERA",
    "CH04","CH06","CH07","CH08","NIVEL_ED","ESTADO","CAT_INAC","IPCF",
    "CH15","PP02H","PP02I","PP10A","T_VI","ITF","PP02E"
]

# Trabajamos sobre copias y normalizamos nombres a MAYÚSCULAS
b2005_chk = base_2005.copy()
b2025_chk = base_2025.copy()
b2005_chk.columns = [c.upper() for c in b2005_chk.columns]
b2025_chk.columns = [c.upper() for c in b2025_chk.columns]

# Subconjuntos solo con las columnas presentes en cada base
b2005_chk = b2005_chk[[c for c in vars_keep if c in b2005_chk.columns]]
b2025_chk = b2025_chk[[c for c in vars_keep if c in b2025_chk.columns]]

# Tipos por base
print("📊 DTA 2005 dtypes (sin conversiones):\n", b2005_chk.dtypes)
print("\n📊 XLSX 2025 dtypes (sin conversiones):\n", b2025_chk.dtypes)

# Comparación lado a lado
comparacion = []
for col in sorted(set(b2005_chk.columns).union(set(b2025_chk.columns))):
    comparacion.append({
        "Variable": col,
        "En_2005": col in b2005_chk.columns,
        "Dtype_2005": str(b2005_chk[col].dtype) if col in b2005_chk.columns else None,
        "En_2025": col in b2025_chk.columns,
        "Dtype_2025": str(b2025_chk[col].dtype) if col in b2025_chk.columns else None,
        "Coincide": (str(b2005_chk[col].dtype) == str(b2025_chk[col].dtype))
                    if (col in b2005_chk.columns and col in b2025_chk.columns) else None
    })

comp_df = pd.DataFrame(comparacion)
print("\n🔎 Comparación de dtypes (2005 vs 2025) — sin conversiones:")
print(comp_df)
# Out:
# 📊 DTA 2005 dtypes (sin conversiones):
#  CODUSU          object
# NRO_HOGAR      float64
# COMPONENTE    category
# H15           category
# ANO4           float64
# TRIMESTRE     category
# REGION        category
# PONDERA        float64
# CH04          category
# CH06          category
# CH07          category
# CH08          category
# NIVEL_ED      category
# ESTADO        category
# CAT_INAC      category
# IPCF           float64
# CH15          category
# PP02H         category
# PP02I         category
# PP10A         category
# T_VI           float64
# ITF            float64
# PP02E         category
# dtype: object
#
# 📊 XLSX 2025 dtypes (sin conversiones):
#  CODUSU         object
# NRO_HOGAR       int64
# COMPONENTE      int64
# H15             int64
# ANO4            int64
# TRIMESTRE       int64
# REGION          int64
# PONDERA         int64
# CH04            int64
# CH06            int64
# CH07            int64
# CH08          float64
# NIVEL_ED        int64
# ...

# %%
# =========================
# Convertir dtypes 2005 = dtypes 2025
# =========================
# Mapa de tipos objetivo tomado de la base 2025 (lo que realmente tenés)
target_types = base_2025.dtypes.astype(str).to_dict()

def cast_like_2025(s: pd.Series, target: str) -> pd.Series:
    # Si viene como category, lo paso a string para poder convertir a numérico
    if is_categorical_dtype(s):
        s = s.astype("string")

    if target == "int64":
        s_num = pd.to_numeric(s, errors="coerce")
        # Si hay NA, uso entero "nullable" para no perder info
        if s_num.isna().any():
            return s_num.round().astype("Int64")
        return s_num.round().astype("int64")

    if target == "float64":
        return pd.to_numeric(s, errors="coerce").astype("float64")

    if target == "object":
        # Mantengo como objeto/texto
        return s.astype("object")

    # Fallback genérico (no debería usarse acá)
    return s.astype(target)

# Aplico conversión solo a columnas comunes
cols_comunes = [c for c in base_2005.columns if c in target_types]
for c in cols_comunes:
    base_2005[c] = cast_like_2025(base_2005[c], target_types[c])

# Control post-conversión
print("📊 DTA 2005 dtypes (después de convertir):\n", base_2005[cols_comunes].dtypes)
print("\n📊 XLSX 2025 dtypes (referencia):\n", base_2025[cols_comunes].dtypes)

# Comparación lado a lado
cmp = []
for c in cols_comunes:
    cmp.append({
        "Variable": c,
        "2005": str(base_2005[c].dtype),
        "2025": str(base_2025[c].dtype),
        "Coincide": str(base_2005[c].dtype) == str(base_2025[c].dtype)
    })
print("\n🔎 Comparación dtypes por columna:")
print(pd.DataFrame(cmp))

# =========================
# Guardar bases
# =========================
out_dir = r"C:\Users\AGUSTIN\Desktop"

# Excel (lo más práctico)
base_2005.to_excel(fr"{out_dir}\EPH_individual_2005_armonizada.xlsx", index=False)
base_2025.to_excel(fr"{out_dir}\EPH_individual_2025_filtrada.xlsx", index=False)
# Out:
# 📊 DTA 2005 dtypes (después de convertir):
#  CODUSU         object
# NRO_HOGAR       int64
# COMPONENTE      int64
# H15             Int64
# ANO4            int64
# TRIMESTRE       Int64
# REGION          Int64
# PONDERA         int64
# CH04            Int64
# CH06            Int64
# CH07            Int64
# CH08          float64
# NIVEL_ED        Int64
# ESTADO          Int64
# CAT_INAC        Int64
# IPCF          float64
# CH15            Int64
# PP02H           Int64
# PP02I           Int64
# PP10A         float64
# T_VI            int64
# ITF             int64
# PP02E           Int64
# dtype: object
#
# 📊 XLSX 2025 dtypes (referencia):
#  CODUSU         object
# NRO_HOGAR       int64
# COMPONENTE      int64
# H15             int64
# ANO4            int64
# TRIMESTRE       int64
# REGION          int64
# PONDERA         int64
# CH04            int64
# CH06            int64
# CH07            int64
# CH08          float64
# NIVEL_ED        int64
# ESTADO          int64
# ...

# %%
# Parte 3 | Fran



#
