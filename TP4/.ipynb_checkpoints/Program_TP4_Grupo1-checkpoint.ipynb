# %%
# Paquetes empleados
import os 
import pandas as pd # Manipulacion de datos
import numpy as np # Calculos numericos
import matplotlib.pyplot as plt # Graficos
import seaborn as sns # Grafico
import statsmodels.api as sm     
from sklearn.linear_model import LogisticRegression, Lasso, LassoCV, Ridge, RidgeCV, ElasticNet, ElasticNetCV
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, accuracy_score
from sklearn.metrics import RocCurveDisplay
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler, scale # Estandarizacion de datos

# %%
# IMPORTAMOS LA BASE
#C:\Users\Usuario\Desktop\Maestria\Programacion\BigDataUBA-Grupo1\TP3\bases - Ruta juan pc escritorio
#r"C:\Users\AGUSTIN\Desktop\TP" - Ruta Agus
# C:\Repositorios\BigDataUBA-Grupo1\TP3\bases - Ruta Fran

base= pd.read_excel(r"C:\Users\Usuario\Desktop\Maestria\Programacion\BigDataUBA-Grupo1\TP3\bases\respondieron_2025.xlsx")

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4128 entries, 0 to 4156
# Data columns (total 44 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODUSU                   4128 non-null   object
#  1   NRO_HOGAR                4128 non-null   int64
#  2   COMPONENTE               4128 non-null   int64
#  3   H15                      4128 non-null   int64
#  4   ANO4                     4128 non-null   int64
#  5   TRIMESTRE                4128 non-null   int64
#  6   REGION                   4128 non-null   int64
#  7   PONDERA                  4128 non-null   int64
#  8   CH03                     4128 non-null   int64
#  9   CH04                     4128 non-null   int64
#  10  CH06                     4128 non-null   int64
#  11  CH07                     4128 non-null   int64
#  12  CH08                     4128 non-null   int64
#  13  NIVEL_ED                 4128 non-null   int64
#  14  ESTADO                   4128 non-null   int64
#  15  CAT_INAC                 4128 non-null   int64
#  16  IPCF                     4128 non-null   float64
#  17  CH10                     4128 non-null   int64
#  18  CH12                     4128 non-null   int64
#  19  CH13                     4128 non-null   int64
#  20  CH14                     1992 non-null   float64
#  21  CH15                     4128 non-null   int64
#  22  PP02H                    4128 non-null   int64
#  23  PP02I                    4128 non-null   int64
#  24  PP10A                    100 non-null    float64
#  25  PP3E_TOT                 1789 non-null   float64
#  26  PP3F_TOT                 1790 non-null   float64
#  27  T_VI                     4128 non-null   int64
#  28  ITF                      4128 non-null   int64
#  29  PP02E                    4128 non-null   int64
#  30  PERIODO                  4128 non-null   object
#  31  respondieron             4128 non-null   bool
#  32  adult_eq                 4128 non-null   float64
#  33  ad_equiv_hogar           4128 non-null   float64
#  34  ingreso_necesario        4128 non-null   float64
#  35  pobre                    4128 non-null   int64
#  36  edad2                    4128 non-null   int64
#  37  educ                     4128 non-null   float64
#  38  factor_de_actualizacion  4128 non-null   int64
#  39  ingreso_total_familiar   4128 non-null   int64
#  40  ingreso_necesario_act    4128 non-null   float64
#  41  es_jefe                  4128 non-null   int64
#  42  horastrab                4128 non-null   int64
#  43  IX_TOT                   4128 non-null   int64
# dtypes: bool(1), float64(10), int64(31), object(2)
# memory usage: 1.4+ MB

# %%
base=base.dropna(subset=['educ'])

# %%
# VARIABLES EXPLICATIVAS y dependiente y separacion en train y test
vars_X = [
    "educ", "CH06", "edad2", "horastrab",
    "CH04", "IX_TOT", "CH07",
    "CH08", "ESTADO"
]

X=base[vars_X]
y= base['pobre']

# Corte 70/30
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=444)
